# %%
import seaborn as sns
df=sns.load_dataset("titanic")    # importing titanic data set
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()         # checking for null values
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.dropna().shape   #checking no. of rows and columns
# Out:
# (182, 15)

# %%
((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100   #checking the percentage of null values
# Out:
# 79.57351290684625

# %%
(df.isna().sum()/df.shape[0])*100    #checking the percentage of null values
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df = df.drop(columns=['deck'])    #removing deck column from dataset

# %%
df.columns    #to get column names
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %% [markdown]
# # UNIVARIATE
# #### drawing graphs for one variable

# %%
import matplotlib.pyplot as plt  # importing libraries for creating graphs

# %% [markdown]
# # 1. histplot

# %%
plt.figure(figsize=(5,5))
sns.histplot (x=df['survived']) # hostplot for x-axis = survived
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot (x=df['age']) # hostplot for x-axis = age
plt.show()

# %% [markdown]
# # scatterplot for numeric and numeric

# %%
df.info()  #to get information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %% [markdown]
# # 2. scatterplot
# ### *for scatterplot in x=numeric and y=numeric*

# %% [markdown]
# # bivariate
# ## draw the graphs with two variables in x-axis and y-axis

# %%
# bivariate 
#1
plt.figure()
sns.scatterplot(x=df['age'],y=df['fare'])  #for age and fare scatterplot
plt.show()

# %% [markdown]
# ## for age and parch scatterplot

# %%
#2
plt.figure()
sns.scatterplot(x=df['age'],y=df['parch'])  #for age and parch scatterplot
plt.show()

# %% [markdown]
# ## for age and sibsp scatterplot

# %%
#3
plt.figure()
sns.scatterplot(x=df['age'],y=df['sibsp']) #for age and sibsp scatterplot
plt.show()

# %% [markdown]
# ## for age and pclass scatterplot

# %%
#4
plt.figure()
sns.scatterplot(x=df['age'],y=df['pclass'])  #for age and pclass scatterplot
plt.show()

# %% [markdown]
# ## for age and survived scatterplot

# %%
#5
plt.figure()
sns.scatterplot(x=df['age'],y=df['survived']) #for age and survived scatterplot
plt.show()

# %% [markdown]
# ## for survived-sibsp

# %%
#6
plt.figure()
sns.scatterplot(x=df['survived'],y=df['sibsp']) #for survived and sibsp scatterplot
plt.show()

# %%
#7
plt.figure()
sns.scatterplot(x=df['survived'],y=df['pclass']) # for survived and pclass
plt.show()

# %%
#8
plt.figure()
sns.scatterplot(x=df['survived'],y=df['fare'])  # for survived and fare
plt.show()

# %%
#9
plt.figure()
sns.scatterplot(x=df['survived'],y=df['parch']) #for survived and parch scatterplot
plt.show()

# %%
#10
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['pclass'])   # for sibsp and pclass
plt.show()

# %%
#11
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['fare'])   # for sibsp and fare
plt.show()

# %%
#12
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['parch'])  # for sibsp and parch
plt.show()

# %%
#13
plt.figure()
sns.scatterplot(x=df['pclass'],y=df['fare'])  #for pclass and fare scatterplot
plt.show()

# %%
#14
plt.figure()
sns.scatterplot(x=df['parch'],y=df['fare']) ##for parch and fare scatterplot
plt.show()

# %%
#15
plt.figure()
sns.scatterplot(x=df['pclass'],y=df['parch'])  #for pclass and parch scatterplot
plt.show()

# %% [markdown]
# # barplot
# ## for bar we use x=numerical and y=categorical

# %% [markdown]
# # 1. for x= sex and y= pclass

# %%
#1
plt.figure()
sns.barplot(x=df['sex'],y=df['pclass'])  # for sex and pclass barchart
plt.show()

# %%
#2
plt.figure()
sns.barplot(x=df['sex'],y=df['age']) # for sex and age
plt.show()

# %%
#3
plt.figure()
sns.barplot(x=df['sex'],y=df['sibsp']) # for sex and sibsp
plt.show()

# %%
df.info() # for information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
#4
plt.figure()
sns.barplot(x=df['sex'],y=df['survived']) # for sex and survived
plt.show()

# %%
#5
plt.figure()
sns.barplot(x=df['sex'],y=df['parch']) # for sex and parch
plt.show()

# %%
#6
plt.figure()
sns.barplot(x=df['sex'],y=df['fare']) # for sex and fare
plt.show()

# %% [markdown]
# ## 2.for x= class and y= fare

# %%
#7
plt.figure()
sns.barplot(x=df['class'],y=df['fare']) # for class and fare
plt.show()

# %%
#8
plt.figure()
sns.barplot(x=df['class'],y=df['parch']) # for class and parch
plt.show()

# %%
#9
plt.figure()
sns.barplot(x=df['class'],y=df['sibsp']) # for class and sibsp
plt.show()

# %%
#10
plt.figure()
sns.barplot(x=df['class'],y=df['age']) # for class and age
plt.show()

# %%
#11
plt.figure()
sns.barplot(x=df['class'],y=df['pclass']) # for class and pclass
plt.show()

# %%
#12
plt.figure()
sns.barplot(x=df['class'],y=df['survived']) # for class and survived
plt.show()

# %% [markdown]
# ## 3. for x=embarked(category) and y=(numeric)

# %%
#13
plt.figure()
sns.barplot(x=df['embarked'],y=df['survived']) # for embarked and survived
plt.show()

# %%
#14
plt.figure()
sns.barplot(x=df['embarked'],y=df['pclass']) # for embarked and pclasss
plt.show()

# %%
#15
plt.figure()
sns.barplot(x=df['embarked'],y=df['age']) # for embarked and age
plt.show()

# %%
#16
plt.figure()
sns.barplot(x=df['embarked'],y=df['sibsp']) # for embarked and sibsp
plt.show()

# %%
#17
plt.figure()
sns.barplot(x=df['embarked'],y=df['parch']) # for embarked and parch
plt.show()

# %%
#18
plt.figure()
sns.barplot(x=df['embarked'],y=df['fare']) # for embarked and fare
plt.show()

# %% [markdown]
# ## 4. for x=who(category) and y=(numeric)

# %%
#19
plt.figure()
sns.barplot(x=df['who'],y=df['fare']) # for who and fare
plt.show()

# %%
#20
plt.figure()
sns.barplot(x=df['who'],y=df['parch']) # for who and parch
plt.show()

# %%
#21
plt.figure()
sns.barplot(x=df['who'],y=df['sibsp']) # for who and sibsp
plt.show()

# %%
#22
plt.figure()
sns.barplot(x=df['who'],y=df['age']) # for who and age
plt.show()

# %%
#23
plt.figure()
sns.barplot(x=df['who'],y=df['pclass']) # for who and pclass
plt.show()

# %%
#24
plt.figure()
sns.barplot(x=df['who'],y=df['survived']) # for who and survived
plt.show()

# %%
#25
plt.figure()
sns.barplot(x=df['adult_male'],y=df['fare']) # for  adult_male and fare
plt.show()

# %%
#26
plt.figure()
sns.barplot(x=df['adult_male'],y=df['parch']) # for  adult_male and parch
plt.show()

# %%
#27
plt.figure()
sns.barplot(x=df['adult_male'],y=df['sibsp']) # for  adult_male and sibsp
plt.show()

# %%
#28
plt.figure()
sns.barplot(x=df['adult_male'],y=df['age']) # for  adult_male and age
plt.show()

# %%
#29
plt.figure()
sns.barplot(x=df['adult_male'],y=df['pclass']) # for  adult_male and pclass
plt.show()

# %%
#30
plt.figure()
sns.barplot(x=df['adult_male'],y=df['survived']) # for  adult_male and survivved
plt.show()

# %%
#31
plt.figure()
sns.barplot(x=df['embark_town'],y=df['survived']) # for  embark_town and survivved
plt.show()

# %%
#32
plt.figure()
sns.barplot(x=df['embark_town'],y=df['pclass']) # for  embark_town and pclass
plt.show()

# %%
#33
plt.figure()
sns.barplot(x=df['embark_town'],y=df['age']) # for  embark_town and age
plt.show()

# %%
#34
plt.figure()
sns.barplot(x=df['embark_town'],y=df['sibsp']) # for  embark_town and sibsp
plt.show()

# %%
#35
plt.figure()
sns.barplot(x=df['embark_town'],y=df['parch']) # for  embark_town and survivved
plt.show()

# %%
#36
plt.figure()
sns.barplot(x=df['embark_town'],y=df['fare']) # for  embark_town and fare
plt.show()

# %%
#37
plt.figure()
sns.barplot(x=df['alive'],y=df['fare']) # for  alive and fare
plt.show()

# %%
#38
plt.figure()
sns.barplot(x=df['alive'],y=df['parch']) # for  alive and parch
plt.show()

# %%
#39
plt.figure()
sns.barplot(x=df['alive'],y=df['sibsp']) # for  alive and sibsp
plt.show()

# %%
#40
plt.figure()
sns.barplot(x=df['alive'],y=df['age']) # for  alive and age
plt.show()

# %%
#41
plt.figure()
sns.barplot(x=df['alive'],y=df['pclass']) # for  alive and pclass
plt.show()

# %%
#42
plt.figure()
sns.barplot(x=df['alive'],y=df['survived']) # for  alive and survived
plt.show()

# %%
#43
plt.figure()
sns.barplot(x=df['alone'],y=df['survived']) # for  alone and survived
plt.show()

# %%
#44
plt.figure()
sns.barplot(x=df['alone'],y=df['pclass']) # for  alone and pclass
plt.show()

# %%
#45
plt.figure()
sns.barplot(x=df['alone'],y=df['age']) # for  alone and age
plt.show()

# %%
#46
plt.figure()
sns.barplot(x=df['alone'],y=df['sibsp']) # for  alone and sibsp
plt.show()

# %%
#47
plt.figure()
sns.barplot(x=df['alone'],y=df['parch']) # for  alone and parch
plt.show()

# %%
#48
plt.figure()
sns.barplot(x=df['alone'],y=df['fare']) # for  alone and fare
plt.show()

# %% [markdown]
# # 4 boxplot
# ### they are two types i.univarient and ii.bivarient

# %% [markdown]
# # i. univarient  with one axis x or y(numeric)

# %%
#1
sns.boxplot(x=df['pclass']) #boxplot for pclass
plt.show()

# %%
#2
sns.boxplot(x=df['survived']) #boxplot for survived
plt.show()

# %%
#3
sns.boxplot(x=df['age'])  #boxplot for age
plt.show()

# %%
#4
sns.boxplot(x=df['sibsp'])   #boxplot for sibsp
plt.show()

# %%
#5
sns.boxplot(x=df['parch']) #boxplot for parch
plt.show()

# %%
#6
sns.boxplot(x=df['fare'])   #boxplot for fare
plt.show()

# %% [markdown]
# # ii. bivariate
# ## with two axis(x and y) in  x-axis = category and y axis = numeric

# %% [markdown]
# ## 1. for sex(catagoey) and age(numeric)

# %%
#1
sns.boxplot(x=df['sex'],y=df['age'],palette='Set1')  # Set1, Pastel1, Blues, Reds used for colours
plt.show()  #for sex and age
# Out:
# C:\Users\yadav\AppData\Local\Temp\ipykernel_23768\3203178198.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['sex'],y=df['age'],palette='Set1')  # Set1, Pastel1, Blues, Reds used for colours

# %%
#2
sns.boxplot(x=df['sex'],y=df['survived'])  #for sex and survived
plt.show()

# %%
#3
sns.boxplot(x=df['sex'],y=df['pclass'])  #for sex and pclass
plt.show()

# %%
#4
sns.boxplot(x=df['sex'],y=df['sibsp'])  #for sex and sibsp
plt.show()

# %%
#5
sns.boxplot(x=df['sex'],y=df['parch']) #for sex and parch
plt.show()

# %%
#6
sns.boxplot(x=df['sex'],y=df['fare']) #for sex and fare
plt.show()

# %%
#7
sns.boxplot(x=df['embarked'],y=df['fare']) #for embarked and fare
plt.show()

# %%
#8
sns.boxplot(x=df['embarked'],y=df['parch']) #for embarked and parch
plt.show()

# %%
#9
sns.boxplot(x=df['embarked'],y=df['sibsp']) #for embarked and sibsp
plt.show()

# %%
#10
sns.boxplot(x=df['embarked'],y=df['age']) #for embarked and age
plt.show()

# %%
#11
sns.boxplot(x=df['embarked'],y=df['pclass']) #for embarked and pclass
plt.show()

# %%
#12
sns.boxplot(x=df['embarked'],y=df['survived']) #for embarked and survived
plt.show()

# %%
#13
sns.boxplot(x=df['class'],y=df['fare']) #for class and fare
plt.show()

# %%
#14
sns.boxplot(x=df['class'],y=df['parch']) #for class and parch
plt.show()

# %%
#15
sns.boxplot(x=df['class'],y=df['sibsp']) #for class and sibsp
plt.show()

# %%
#16
sns.boxplot(x=df['class'],y=df['age']) #for class and age
plt.show()

# %%
#17
sns.boxplot(x=df['class'],y=df['pclass']) #for class and pclass
plt.show()

# %%
#18
sns.boxplot(x=df['class'],y=df['survived']) #for class and survived
plt.show()

# %%
#19
sns.boxplot(x=df['who'],y=df['fare']) #for who and fare
plt.show()

# %%
#20 
sns.boxplot(x=df['who'],y=df['parch']) #for who and parch
plt.show()

# %%
#21
sns.boxplot(x=df['who'],y=df['sibsp']) #for who and sibsp
plt.show()

# %%
#22
sns.boxplot(x=df['who'],y=df['age']) #for who and age
plt.show()

# %%
#23
sns.boxplot(x=df['who'],y=df['pclass']) #for who and pclass
plt.show()

# %%
#24
sns.boxplot(x=df['who'],y=df['survived']) #for who and survived
plt.show()

# %%
#25
sns.boxplot(x=df['adult_male'],y=df['survived']) #for adult_male and survived
plt.show()

# %%
#26
sns.boxplot(x=df['adult_male'],y=df['pclass']) #for adult_male and pclass
plt.show()

# %%
#27
sns.boxplot(x=df['adult_male'],y=df['age']) #for adult_male and age
plt.show()

# %%
#28
sns.boxplot(x=df['adult_male'],y=df['sibsp']) #for adult_male and sibsp
plt.show()

# %%
#29
sns.boxplot(x=df['adult_male'],y=df['parch']) #for adult_male and parch
plt.show()

# %%
#30
sns.boxplot(x=df['adult_male'],y=df['fare']) #for adult_male and fare
plt.show()

# %%
#31
sns.boxplot(x=df['embark_town'],y=df['survived']) #for embark_town and survived
plt.show()

# %%
#32
sns.boxplot(x=df['embark_town'],y=df['pclass']) #for embark_town and pclass
plt.show()

# %%
#33
sns.boxplot(x=df['embark_town'],y=df['age']) #for embark_town and age 
plt.show()

# %%
#34
sns.boxplot(x=df['embark_town'],y=df['sibsp']) #for embark_town and sibsp
plt.show()

# %%
#35
sns.boxplot(x=df['embark_town'],y=df['parch']) #for embark_town and parch
plt.show()

# %%
#36
sns.boxplot(x=df['embark_town'],y=df['fare']) #for embark_town and fare
plt.show()

# %%
#37
sns.boxplot(x=df['alive'],y=df['fare']) #for alive and fare
plt.show()

# %%
#38
sns.boxplot(x=df['alive'],y=df['parch']) #for alive and parch
plt.show()

# %%
#39
sns.boxplot(x=df['alive'],y=df['sibsp']) #for alive and sibsp
plt.show()

# %%
#40
sns.boxplot(x=df['alive'],y=df['age']) #for alive and age
plt.show()

# %%
#41
sns.boxplot(x=df['alive'],y=df['pclass']) #for alive and pclass
plt.show()

# %%
#42
sns.boxplot(x=df['alive'],y=df['survived']) #for alive and survived
plt.show()

# %%
#43
sns.boxplot(x=df['alone'],y=df['fare']) #for alone and fare
plt.show()

# %%
#44
sns.boxplot(x=df['alone'],y=df['parch']) #for alone and parch
plt.show()

# %%
#45
sns.boxplot(x=df['alone'],y=df['sibsp']) #for alone and sibsp
plt.show()

# %%
#46
sns.boxplot(x=df['alone'],y=df['age']) #for alone and age
plt.show()

# %%
#43
sns.boxplot(x=df['alone'],y=df['pclass']) #for alone and pclass
plt.show()

# %%
#43
sns.boxplot(x=df['alone'],y=df['survived']) #for alone and survived
plt.show()

# %% [markdown]
# # 5. stripplot
# # used for where x-axis = category and y-axis = category

# %%
#1
sns.stripplot(x=df['embarked'],y=df['sex']) #for embarked and sex
plt.show()

# %%
#2
sns.stripplot(x=df['embarked'],y=df['class']) #for embarked and sex
plt.show()

# %%
#3
sns.stripplot(x=df['embarked'],y=df['who']) #for embarked and sex
plt.show()

# %%
#4
sns.stripplot(x=df['embarked'],y=df['adult_male']) #for embarked and adult_male
plt.show()

# %%
#5
sns.stripplot(x=df['embarked'],y=df['alive']) #for embarked and alive
plt.show()

# %%
#6
sns.stripplot(x=df['embarked'],y=df['alone']) #for embarked and alone
plt.show()

# %%
#7
sns.stripplot(x=df['sex'],y=df['class']) #for sex and class
plt.show()

# %%
#8
sns.stripplot(x=df['sex'],y=df['who']) #for sex and who
plt.show()

# %%
#9
sns.stripplot(x=df['sex'],y=df['adult_male']) #for srx and adult_male 
plt.show()

# %%
#10
sns.stripplot(x=df['sex'],y=df['embark_town']) #for srx andembark_town 
plt.show()

# %%
#11
sns.stripplot(x=df['sex'],y=df['alive']) #for srx and alive 
plt.show()

# %%
#12
sns.stripplot(x=df['sex'],y=df['alone']) #for srx and alone 
plt.show()

# %%
#13
sns.stripplot(x=df['class'],y=df['alone']) #for class and alone 
plt.show()

# %%
#14
sns.stripplot(x=df['class'],y=df['alive']) #for srx and alive 
plt.show()

# %%
#15
sns.stripplot(x=df['class'],y=df['embark_town']) #for srx and embark_town 
plt.show()

# %%
#16
sns.stripplot(x=df['class'],y=df['adult_male']) #for srx and adult_male 
plt.show()

# %%
#17
sns.stripplot(x=df['class'],y=df['who']) #for class and who 
plt.show()

# %%
#18
sns.stripplot(x=df['who'],y=df['adult_male']) #for who and adult_male 
plt.show()

# %%
#19
sns.stripplot(x=df['who'],y=df['embark_town']) #for who and embark_town 
plt.show()

# %%
#20
sns.stripplot(x=df['who'],y=df['alive']) #for who and alive 
plt.show()

# %%
#21
sns.stripplot(x=df['who'],y=df['alone']) #for who and alone
plt.show()

# %%
#22
sns.stripplot(x=df['adult_male'],y=df['embark_town']) #for adult_male and embark_town 
plt.show()

# %%
#23
sns.stripplot(x=df['adult_male'],y=df['alive']) #for adult_male and alive 
plt.show()

# %%
#24
sns.stripplot(x=df['adult_male'],y=df['alone']) #for adult_male and alone 
plt.show()

# %% [markdown]
# # 6. swarmplot

# %%
#4
sns.swarmplot(x=df['embarked'],y=df['sex']) #for embarked and sex
plt.show()
# Out:
# C:\Users\yadav\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 92.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\yadav\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 70.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\yadav\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 35.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\yadav\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 94.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# # Scattergrah for 3 variables

# %%
# bivariate
plt.figure()
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['pclass'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['survived'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['sibsp'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['sex']) # for survived and pclass
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['sex'])  # for survived and fare
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['pclass'],hue=df['sex'])   # for sibsp and pclass
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['fare'],hue=df['sex'])   # for sibsp and fare
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['parch'],hue=df['sex'])  # for sibsp and parch
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['sibsp'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'],y=df['fare'],hue=df['sex'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'],y=df['fare'],hue=df['embarked'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['sibsp'],hue=df['embarked'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['parch'],hue=df['embarked'])  # for sibsp and parch
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['fare'],hue=df['embarked'])   # for sibsp and fare
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'],y=df['pclass'],hue=df['embarked'])   # for sibsp and pclass
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['embarked'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['embarked'])  # for survived and fare
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['embarked']) # for survived and pclass
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['sibsp'],hue=df['embarked'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['survived'],hue=df['embarked'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['pclass'],hue=df['embarked'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['embarked'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['embarked'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['embarked'])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['pclass'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'],y=df['survived'],hue=df['class'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'],y=df['sibsp'],hue=df['class'])
plt.show()

# %% [markdown]
# # bargraph for 3 variables

# %%
#1
plt.figure()
sns.barplot(x=df['sex'],y=df['pclass'],hue=df['class'])
plt.show()

# %%
#2
plt.figure()
sns.barplot(x=df['sex'],y=df['age'],hue=df['class']) # for sex and age
plt.show()

# %%
#3
plt.figure()
sns.barplot(x=df['sex'],y=df['sibsp'],hue=df['class'],dodge=True) # for sex and sibsp
plt.show()

# %%
#4
plt.figure()
sns.barplot(x=df['sex'],y=df['survived'],hue=df['class'],dodge=True) # for sex and sibsp
plt.show()

# %%
#5
plt.figure()
sns.barplot(x=df['sex'],y=df['parch'],hue=df['class'],dodge=True) # for sex and sibsp
plt.show()

# %%
#6
plt.figure()
sns.barplot(x=df['sex'],y=df['fare'],hue=df['class'],dodge=True) # for sex and sibsp
plt.show()

# %%
#7
plt.figure()
sns.barplot(x=df['embarked'],y=df['survived'],hue=df['class'],dodge=True) # for sex and sibsp
plt.show()
